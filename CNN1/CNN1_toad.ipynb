# %%
#Import Libraries

import numpy as np
from keras import backend as K
from keras.models import Sequential
#from keras.layers.core import Dense, Dropout, Activation, Flatten
#from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, MaxPooling2D
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from datetime import datetime

# %%
train_data_path ='C:\\Users\\sazid\\Desktop\\jour_data\\toad_background_CNN1\\train'
valid_data_path = 'C:\\Users\\sazid\\Desktop\\jour_data\\toad_background_CNN1\\valid'
test_data_path = 'C:\\Users\\sazid\\Desktop\\jour_data\\toad_background_CNN1\\test'

# %%
# Set image size, batch size, sample number and epochs

img_rows = 150
img_cols = 150
epochs = 100
batch_size = 32
num_of_train_samples = 2500 
num_of_valid_samples = 500


############################################
# Set Data Generator for training, testing and validataion.
# Note for testing, set shuffle = false (For proper Confusion matrix)

 # This will do preprocessing and realtime data augmentation:
 # this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(rescale=1. / 255,
                                   rotation_range=15, # randomly rotate images in the range 
                                                      # (degrees, 0 to 40)
                                   width_shift_range=0.1, # randomly shift images horizontally 
                                                          # (fraction of total width)
                                   height_shift_range=0.1,# randomly shift images vertically 
                                                          # (fraction of total height)
                                   shear_range=10, #shear_range is for randomly applying shearing transformations
                                   zoom_range=0.15, #randomly zooming inside pictures
                                   horizontal_flip=True, # randomly flip images
                                   fill_mode='nearest')

# batches of augmented image data
train_generator = train_datagen.flow_from_directory(train_data_path, # this is the target directory
                                                    target_size=(img_rows, img_cols),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1. / 255)
valid_datagen = ImageDataGenerator(rescale=1. / 255)
                                                    
# this is a similar generator, for validation data
validation_generator = valid_datagen.flow_from_directory(valid_data_path,
                                                        target_size=(img_rows, img_cols),
                                                        batch_size=batch_size,
                                                        shuffle=True,
                                                        class_mode='categorical')
                                                        
 # this is a similar generator, for test data                                                       
test_generator = test_datagen.flow_from_directory(test_data_path,
                                                        target_size=(img_rows, img_cols),
                                                        batch_size=batch_size,
                                                        shuffle=False,
                                                        class_mode='categorical')
# Out:
# Found 2500 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
#Model Creation / Sequential

model = Sequential()

model.add(Conv2D((32), (3, 3), input_shape=(img_rows, img_cols, 3), kernel_initializer="glorot_uniform"))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D((32), (3, 3),kernel_initializer="glorot_uniform"))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D((64), (3, 3),kernel_initializer="glorot_uniform"))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


model.add(Flatten())  # this converts our 3D feature maps to 1D feature vector

model.add(Dense(128))
model.add(Activation('relu'))
#model.add(Dropout(0.20))


model.add(Dense(2))
model.add(Activation('softmax'))

#Get summary of the model
model.summary()

#Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])

#Train the model

history=model.fit(train_generator,
                    steps_per_epoch=num_of_train_samples // batch_size,
                    epochs=epochs,
                    validation_data=validation_generator,
                    validation_steps=num_of_valid_samples // batch_size)
                    
#You can use model.save(filepath) to save a Keras model into a single HDF5 file which will contain:
                    
model.save("toad.h5")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 148, 148, 32)      128
# _________________________________________________________________
# activation_10 (Activation)   (None, 148, 148, 32)      0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 72, 72, 32)        128
# _________________________________________________________________
# activation_11 (Activation)   (None, 72, 72, 32)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 34, 34, 64)        256
# _________________________________________________________________
# activation_12 (Activation)   (None, 34, 34, 64)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               2367616
# _________________________________________________________________
# activation_13 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 258
# _________________________________________________________________
# activation_14 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 2,397,026
# Trainable params: 2,396,770
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/100
# 78/78 [==============================] - 104s 1s/step - loss: 2.7872 - acc: 0.7707 - val_loss: 0.4456 - val_acc: 0.8479
# Epoch 2/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.2952 - acc: 0.8930 - val_loss: 0.6072 - val_acc: 0.6354
# Epoch 3/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.2916 - acc: 0.8856 - val_loss: 0.7810 - val_acc: 0.5854
# Epoch 4/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.4796 - acc: 0.8621 - val_loss: 0.3863 - val_acc: 0.8583
# Epoch 5/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.2157 - acc: 0.9093 - val_loss: 0.3285 - val_acc: 0.8229
# Epoch 6/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.1835 - acc: 0.9296 - val_loss: 0.2242 - val_acc: 0.9000
# Epoch 7/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.2113 - acc: 0.9064 - val_loss: 0.1795 - val_acc: 0.9229
# Epoch 8/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.1702 - acc: 0.9336 - val_loss: 0.1147 - val_acc: 0.9688
# Epoch 9/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.1748 - acc: 0.9344 - val_loss: 0.1157 - val_acc: 0.9688
# Epoch 10/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.1530 - acc: 0.9403 - val_loss: 0.1459 - val_acc: 0.9312
# Epoch 11/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.1550 - acc: 0.9439 - val_loss: 0.1010 - val_acc: 0.9688
# Epoch 12/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.1298 - acc: 0.9528 - val_loss: 0.0951 - val_acc: 0.9604
# Epoch 13/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.1617 - acc: 0.9318 - val_loss: 0.0881 - val_acc: 0.9792
# Epoch 14/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.1408 - acc: 0.9418 - val_loss: 0.1643 - val_acc: 0.9396
# Epoch 15/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.1404 - acc: 0.9419 - val_loss: 0.4536 - val_acc: 0.7437
# Epoch 16/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.1226 - acc: 0.9450 - val_loss: 0.0850 - val_acc: 0.9771
# Epoch 17/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.1087 - acc: 0.9617 - val_loss: 0.1866 - val_acc: 0.9312
# Epoch 18/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.1564 - acc: 0.9398 - val_loss: 0.1534 - val_acc: 0.9458
# Epoch 19/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.1069 - acc: 0.9571 - val_loss: 0.3233 - val_acc: 0.9104
# Epoch 20/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.1081 - acc: 0.9577 - val_loss: 0.2811 - val_acc: 0.9062
# Epoch 21/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.1273 - acc: 0.9574 - val_loss: 0.0604 - val_acc: 0.9771
# Epoch 22/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.1617 - acc: 0.9386 - val_loss: 0.1449 - val_acc: 0.9500
# Epoch 23/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0927 - acc: 0.9630 - val_loss: 0.5058 - val_acc: 0.8792
# Epoch 24/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.1065 - acc: 0.9665 - val_loss: 0.0821 - val_acc: 0.9667
# Epoch 25/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.1291 - acc: 0.9507 - val_loss: 0.1454 - val_acc: 0.9417
# Epoch 26/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0900 - acc: 0.9691 - val_loss: 1.0997 - val_acc: 0.6896
# Epoch 27/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0990 - acc: 0.9627 - val_loss: 0.1105 - val_acc: 0.9563
# Epoch 28/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.1132 - acc: 0.9543 - val_loss: 0.2886 - val_acc: 0.9062
# Epoch 29/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0894 - acc: 0.9656 - val_loss: 0.0506 - val_acc: 0.9854
# Epoch 30/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0787 - acc: 0.9726 - val_loss: 0.7096 - val_acc: 0.8708
# Epoch 31/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0898 - acc: 0.9660 - val_loss: 0.0857 - val_acc: 0.9667
# Epoch 32/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0911 - acc: 0.9703 - val_loss: 0.0663 - val_acc: 0.9792
# Epoch 33/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0861 - acc: 0.9734 - val_loss: 1.6141 - val_acc: 0.5542
# Epoch 34/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0907 - acc: 0.9716 - val_loss: 0.2669 - val_acc: 0.9146
# Epoch 35/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0973 - acc: 0.9680 - val_loss: 0.5985 - val_acc: 0.7250
# Epoch 36/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.0824 - acc: 0.9736 - val_loss: 0.0913 - val_acc: 0.9750
# Epoch 37/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0695 - acc: 0.9780 - val_loss: 0.3176 - val_acc: 0.8854
# Epoch 38/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.1167 - acc: 0.9545 - val_loss: 0.2787 - val_acc: 0.9146
# Epoch 39/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0821 - acc: 0.9768 - val_loss: 0.1756 - val_acc: 0.9542
# Epoch 40/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0820 - acc: 0.9745 - val_loss: 0.2434 - val_acc: 0.9167
# Epoch 41/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0773 - acc: 0.9709 - val_loss: 0.0725 - val_acc: 0.9729
# Epoch 42/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0745 - acc: 0.9759 - val_loss: 0.7056 - val_acc: 0.8833
# Epoch 43/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0656 - acc: 0.9807 - val_loss: 0.0509 - val_acc: 0.9875
# Epoch 44/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0735 - acc: 0.9773 - val_loss: 0.1051 - val_acc: 0.9688
# Epoch 45/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0577 - acc: 0.9821 - val_loss: 0.0609 - val_acc: 0.9875
# Epoch 46/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0579 - acc: 0.9794 - val_loss: 0.1506 - val_acc: 0.9583
# Epoch 47/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0720 - acc: 0.9738 - val_loss: 0.0796 - val_acc: 0.9708
# Epoch 48/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.1242 - acc: 0.9489 - val_loss: 0.0724 - val_acc: 0.9729
# Epoch 49/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0959 - acc: 0.9673 - val_loss: 0.6098 - val_acc: 0.7625
# Epoch 50/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0749 - acc: 0.9765 - val_loss: 0.0719 - val_acc: 0.9854
# Epoch 51/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0791 - acc: 0.9721 - val_loss: 0.7271 - val_acc: 0.7437
# Epoch 52/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0747 - acc: 0.9794 - val_loss: 0.2477 - val_acc: 0.9312
# Epoch 53/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0595 - acc: 0.9831 - val_loss: 0.0798 - val_acc: 0.9750
# Epoch 54/100
# 78/78 [==============================] - 98s 1s/step - loss: 0.0557 - acc: 0.9809 - val_loss: 0.0911 - val_acc: 0.9583
# Epoch 55/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0685 - acc: 0.9751 - val_loss: 0.1464 - val_acc: 0.9646
# Epoch 56/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.0887 - acc: 0.9684 - val_loss: 0.1195 - val_acc: 0.9688
# Epoch 57/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.0691 - acc: 0.9747 - val_loss: 0.1116 - val_acc: 0.9688
# Epoch 58/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.0646 - acc: 0.9792 - val_loss: 3.9817 - val_acc: 0.5333
# Epoch 59/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0701 - acc: 0.9794 - val_loss: 0.0586 - val_acc: 0.9771
# Epoch 60/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0614 - acc: 0.9789 - val_loss: 0.0789 - val_acc: 0.9833
# Epoch 61/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.0686 - acc: 0.9778 - val_loss: 0.0596 - val_acc: 0.9792
# Epoch 62/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0534 - acc: 0.9865 - val_loss: 0.1112 - val_acc: 0.9750
# Epoch 63/100
# 78/78 [==============================] - 95s 1s/step - loss: 0.0524 - acc: 0.9836 - val_loss: 0.0724 - val_acc: 0.9812
# Epoch 64/100
# 78/78 [==============================] - 94s 1s/step - loss: 0.0582 - acc: 0.9812 - val_loss: 0.9031 - val_acc: 0.7958
# Epoch 65/100
# 78/78 [==============================] - 94s 1s/step - loss: 0.0975 - acc: 0.9634 - val_loss: 0.0989 - val_acc: 0.9688
# Epoch 66/100
# 78/78 [==============================] - 95s 1s/step - loss: 0.0685 - acc: 0.9791 - val_loss: 0.0590 - val_acc: 0.9792
# Epoch 67/100
# 78/78 [==============================] - 101s 1s/step - loss: 0.0726 - acc: 0.9756 - val_loss: 0.1792 - val_acc: 0.9333
# Epoch 68/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.0649 - acc: 0.9810 - val_loss: 0.0553 - val_acc: 0.9729
# Epoch 69/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0484 - acc: 0.9859 - val_loss: 0.0437 - val_acc: 0.9875
# Epoch 70/100
# 78/78 [==============================] - 96s 1s/step - loss: 0.0596 - acc: 0.9778 - val_loss: 0.0963 - val_acc: 0.9750
# Epoch 71/100
# 78/78 [==============================] - 94s 1s/step - loss: 0.0654 - acc: 0.9774 - val_loss: 0.0639 - val_acc: 0.9729
# Epoch 72/100
# 78/78 [==============================] - 95s 1s/step - loss: 0.0552 - acc: 0.9814 - val_loss: 0.0857 - val_acc: 0.9625
# Epoch 73/100
# 78/78 [==============================] - 94s 1s/step - loss: 0.0601 - acc: 0.9804 - val_loss: 0.0683 - val_acc: 0.9854
# Epoch 74/100
# 78/78 [==============================] - 94s 1s/step - loss: 0.0522 - acc: 0.9870 - val_loss: 0.1610 - val_acc: 0.9438
# Epoch 75/100
# 78/78 [==============================] - 95s 1s/step - loss: 0.0575 - acc: 0.9797 - val_loss: 0.0491 - val_acc: 0.9854
# Epoch 76/100
# 78/78 [==============================] - 94s 1s/step - loss: 0.0592 - acc: 0.9797 - val_loss: 0.0442 - val_acc: 0.9854
# Epoch 77/100
# 78/78 [==============================] - 94s 1s/step - loss: 0.0667 - acc: 0.9762 - val_loss: 0.1609 - val_acc: 0.9500
# Epoch 78/100
# 78/78 [==============================] - 97s 1s/step - loss: 0.0679 - acc: 0.9804 - val_loss: 0.0591 - val_acc: 0.9792
# Epoch 79/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0602 - acc: 0.9783 - val_loss: 0.1184 - val_acc: 0.9646
# Epoch 80/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.0532 - acc: 0.9836 - val_loss: 0.0337 - val_acc: 0.9875
# Epoch 81/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0516 - acc: 0.9829 - val_loss: 0.0404 - val_acc: 0.9875
# Epoch 82/100
# 78/78 [==============================] - 94s 1s/step - loss: 0.0551 - acc: 0.9792 - val_loss: 0.0414 - val_acc: 0.9812
# Epoch 83/100
# 78/78 [==============================] - 97s 1s/step - loss: 0.0481 - acc: 0.9831 - val_loss: 0.0737 - val_acc: 0.9771
# Epoch 84/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.0518 - acc: 0.9842 - val_loss: 0.0679 - val_acc: 0.9812
# Epoch 85/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.0467 - acc: 0.9867 - val_loss: 0.0657 - val_acc: 0.9771
# Epoch 86/100
# 78/78 [==============================] - 102s 1s/step - loss: 0.0557 - acc: 0.9828 - val_loss: 0.0477 - val_acc: 0.9896
# Epoch 87/100
# 78/78 [==============================] - 101s 1s/step - loss: 0.0464 - acc: 0.9847 - val_loss: 0.0430 - val_acc: 0.9937
# Epoch 88/100
# 78/78 [==============================] - 103s 1s/step - loss: 0.0505 - acc: 0.9849 - val_loss: 0.1969 - val_acc: 0.9229
# Epoch 89/100
# 78/78 [==============================] - 94s 1s/step - loss: 0.0565 - acc: 0.9824 - val_loss: 0.0611 - val_acc: 0.9896
# Epoch 90/100
# 78/78 [==============================] - 95s 1s/step - loss: 0.0501 - acc: 0.9817 - val_loss: 0.0405 - val_acc: 0.9875
# Epoch 91/100
# 78/78 [==============================] - 102s 1s/step - loss: 0.0482 - acc: 0.9803 - val_loss: 0.3520 - val_acc: 0.9229
# Epoch 92/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.0350 - acc: 0.9888 - val_loss: 0.0739 - val_acc: 0.9812
# Epoch 93/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.0637 - acc: 0.9795 - val_loss: 1.1649 - val_acc: 0.7063
# Epoch 94/100
# 78/78 [==============================] - 101s 1s/step - loss: 0.0505 - acc: 0.9819 - val_loss: 0.0697 - val_acc: 0.9750
# Epoch 95/100
# 78/78 [==============================] - 105s 1s/step - loss: 0.0521 - acc: 0.9838 - val_loss: 0.1464 - val_acc: 0.9563
# Epoch 96/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.0793 - acc: 0.9750 - val_loss: 1.3095 - val_acc: 0.6708
# Epoch 97/100
# 78/78 [==============================] - 100s 1s/step - loss: 0.0423 - acc: 0.9845 - val_loss: 0.4439 - val_acc: 0.7604
# Epoch 98/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0478 - acc: 0.9833 - val_loss: 0.1671 - val_acc: 0.9479
# Epoch 99/100
# 78/78 [==============================] - 99s 1s/step - loss: 0.0412 - acc: 0.9864 - val_loss: 0.1181 - val_acc: 0.9688
# Epoch 100/100
# 78/78 [==============================] - 101s 1s/step - loss: 0.0443 - acc: 0.9869 - val_loss: 0.0486 - val_acc: 0.9875

# %%
#Plot the Graph

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# Accuracy Curves
plt.figure(1)
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy of Toad Vs Background')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('acc7.png')
plt.show()

# loss Curves
plt.figure(2)
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss of Toad Vs Background')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('loss7.png')
plt.show()

# %%
#Print the Target names
target_names = []
for key in train_generator.class_indices:
    target_names.append(key)
    
print(target_names)
# Out:
# ['background', 'toad']

# %%
#Get the accuracy score
Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
#print('Confusion Matrix')
import itertools
#Plot the confusion matrix. Set Normalize = True/False
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix of all four class', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    #plt.figure(figsize=(8,8))

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    #plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    #plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
   

#thresh = cm.max() / 2.
#Matplotlib’s matshow
cm = confusion_matrix(test_generator.classes, y_pred)

plt.figure(3)
plot_confusion_matrix(cm, target_names, title='Confusion Matrix of Toad Vs Background')
#print(cm)
plt.savefig('lizard.png')
plt.show()
# Out:
# Confusion matrix, without normalization

# %%
#Print Classification Report
print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#   background       0.97      0.95      0.96       100
#         toad       0.95      0.97      0.96       100
#
#     accuracy                           0.96       200
#    macro avg       0.96      0.96      0.96       200
# weighted avg       0.96      0.96      0.96       200
