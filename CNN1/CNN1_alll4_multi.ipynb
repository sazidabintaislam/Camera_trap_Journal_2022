# %%
#Import Libraries

import numpy as np
from keras import backend as K
from keras.models import Sequential
#from keras.layers.core import Dense, Dropout, Activation, Flatten
#from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, MaxPooling2D
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from datetime import datetime

# %%
train_data_path ='C:\\Users\\sazid\\Desktop\\jour_data\\all_three\\train'
valid_data_path = 'C:\\Users\\sazid\\Desktop\\jour_data\\all_three\\valid'
test_data_path = 'C:\\Users\\sazid\\Desktop\\jour_data\\all_three\\test'

# %%
# Set image size, batch size, sample number and epochs

img_rows = 150
img_cols = 150
epochs = 100
batch_size = 32
num_of_train_samples = 5006 
num_of_valid_samples = 1000


############################################
# Set Data Generator for training, testing and validataion.
# Note for testing, set shuffle = false (For proper Confusion matrix)

 # This will do preprocessing and realtime data augmentation:
 # this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(rescale=1. / 255,
                                   rotation_range=15, # randomly rotate images in the range 
                                                      # (degrees, 0 to 40)
                                   width_shift_range=0.1, # randomly shift images horizontally 
                                                          # (fraction of total width)
                                   height_shift_range=0.1,# randomly shift images vertically 
                                                          # (fraction of total height)
                                   shear_range=10, #shear_range is for randomly applying shearing transformations
                                   zoom_range=0.15, #randomly zooming inside pictures
                                   horizontal_flip=True, # randomly flip images
                                   fill_mode='nearest')

# batches of augmented image data
train_generator = train_datagen.flow_from_directory(train_data_path, # this is the target directory
                                                    target_size=(img_rows, img_cols),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1. / 255)
valid_datagen = ImageDataGenerator(rescale=1. / 255)
                                                    
# this is a similar generator, for validation data
validation_generator = valid_datagen.flow_from_directory(valid_data_path,
                                                        target_size=(img_rows, img_cols),
                                                        batch_size=batch_size,
                                                        shuffle=True,
                                                        class_mode='categorical')
                                                        
 # this is a similar generator, for test data                                                       
test_generator = test_datagen.flow_from_directory(test_data_path,
                                                        target_size=(img_rows, img_cols),
                                                        batch_size=batch_size,
                                                        shuffle=False,
                                                        class_mode='categorical')
# Out:
# Found 5006 images belonging to 4 classes.
# Found 1000 images belonging to 4 classes.
# Found 400 images belonging to 4 classes.

# %%
#Model Creation / Sequential

model = Sequential()

model.add(Conv2D((32), (3, 3), input_shape=(img_rows, img_cols, 3), kernel_initializer="glorot_uniform"))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D((32), (3, 3),kernel_initializer="glorot_uniform"))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D((64), (3, 3),kernel_initializer="glorot_uniform"))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D((64), (3, 3),kernel_initializer="glorot_uniform"))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vector

model.add(Dense(128))
model.add(Activation('relu'))
#model.add(Dropout(0.20))

#model.add(Dense(128))
#model.add(Activation('relu'))

model.add(Dense(4))
model.add(Activation('softmax'))

#Get summary of the model
model.summary()

#Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])

#Train the model

history=model.fit(train_generator,
                    steps_per_epoch=num_of_train_samples // batch_size,
                    epochs=epochs,
                    validation_data=validation_generator,
                    validation_steps=num_of_valid_samples // batch_size)
                    
#You can use model.save(filepath) to save a Keras model into a single HDF5 file which will contain:
                    
model.save("all_four_CNN1.h5")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 148, 148, 32)      128
# _________________________________________________________________
# activation (Activation)      (None, 148, 148, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 72, 72, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 72, 72, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 34, 34, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 34, 34, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               401536
# _________________________________________________________________
# activation_4 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 516
# _________________________________________________________________
# activation_5 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 468,388
# Trainable params: 468,004
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/100
# 156/156 [==============================] - 336s 2s/step - loss: 1.4534 - acc: 0.4523 - val_loss: 2.0653 - val_acc: 0.2490
# Epoch 2/100
# 156/156 [==============================] - 309s 2s/step - loss: 0.8729 - acc: 0.6123 - val_loss: 2.1634 - val_acc: 0.2490
# Epoch 3/100
# 156/156 [==============================] - 188s 1s/step - loss: 0.7795 - acc: 0.6655 - val_loss: 1.0068 - val_acc: 0.5373
# Epoch 4/100
# 156/156 [==============================] - 193s 1s/step - loss: 0.7378 - acc: 0.6778 - val_loss: 0.6062 - val_acc: 0.7702
# Epoch 5/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.7142 - acc: 0.7104 - val_loss: 0.5749 - val_acc: 0.7893
# Epoch 6/100
# 156/156 [==============================] - 191s 1s/step - loss: 0.6392 - acc: 0.7270 - val_loss: 0.5903 - val_acc: 0.7954
# Epoch 7/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.6208 - acc: 0.7432 - val_loss: 0.5293 - val_acc: 0.8145
# Epoch 8/100
# 156/156 [==============================] - 191s 1s/step - loss: 0.5889 - acc: 0.7617 - val_loss: 0.6918 - val_acc: 0.7258
# Epoch 9/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.5848 - acc: 0.7605 - val_loss: 0.5032 - val_acc: 0.8145
# Epoch 10/100
# 156/156 [==============================] - 191s 1s/step - loss: 0.5747 - acc: 0.7680 - val_loss: 0.5588 - val_acc: 0.7974
# Epoch 11/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.5517 - acc: 0.7713 - val_loss: 0.8123 - val_acc: 0.6593
# Epoch 12/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.5253 - acc: 0.7922 - val_loss: 0.6324 - val_acc: 0.7440
# Epoch 13/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.5242 - acc: 0.7939 - val_loss: 0.5034 - val_acc: 0.8095
# Epoch 14/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.4979 - acc: 0.7921 - val_loss: 0.4801 - val_acc: 0.8216
# Epoch 15/100
# 156/156 [==============================] - 193s 1s/step - loss: 0.4885 - acc: 0.7973 - val_loss: 1.0192 - val_acc: 0.5786
# Epoch 16/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.4847 - acc: 0.8045 - val_loss: 1.0910 - val_acc: 0.5685
# Epoch 17/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.4431 - acc: 0.8286 - val_loss: 1.4261 - val_acc: 0.5101
# Epoch 18/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.4617 - acc: 0.8119 - val_loss: 0.7535 - val_acc: 0.7026
# Epoch 19/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.4450 - acc: 0.8160 - val_loss: 0.4507 - val_acc: 0.8357
# Epoch 20/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.4563 - acc: 0.8094 - val_loss: 0.5365 - val_acc: 0.7873
# Epoch 21/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.4806 - acc: 0.8111 - val_loss: 0.4100 - val_acc: 0.8427
# Epoch 22/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.4315 - acc: 0.8257 - val_loss: 0.7397 - val_acc: 0.7107
# Epoch 23/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.4409 - acc: 0.8170 - val_loss: 0.6175 - val_acc: 0.7812
# Epoch 24/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3982 - acc: 0.8388 - val_loss: 0.4384 - val_acc: 0.8296
# Epoch 25/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.4144 - acc: 0.8353 - val_loss: 0.4073 - val_acc: 0.8649
# Epoch 26/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.4002 - acc: 0.8474 - val_loss: 0.6412 - val_acc: 0.7510
# Epoch 27/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.4082 - acc: 0.8304 - val_loss: 1.2204 - val_acc: 0.5454
# Epoch 28/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.4201 - acc: 0.8307 - val_loss: 0.5519 - val_acc: 0.8004
# Epoch 29/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3941 - acc: 0.8433 - val_loss: 0.3426 - val_acc: 0.8770
# Epoch 30/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3716 - acc: 0.8552 - val_loss: 0.7743 - val_acc: 0.6925
# Epoch 31/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3966 - acc: 0.8361 - val_loss: 0.5094 - val_acc: 0.8185
# Epoch 32/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3682 - acc: 0.8551 - val_loss: 0.7036 - val_acc: 0.7359
# Epoch 33/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3782 - acc: 0.8438 - val_loss: 0.7986 - val_acc: 0.7329
# Epoch 34/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3651 - acc: 0.8552 - val_loss: 0.4453 - val_acc: 0.8246
# Epoch 35/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3561 - acc: 0.8576 - val_loss: 0.4418 - val_acc: 0.8387
# Epoch 36/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3719 - acc: 0.8492 - val_loss: 0.4836 - val_acc: 0.8165
# Epoch 37/100
# 156/156 [==============================] - 193s 1s/step - loss: 0.3426 - acc: 0.8722 - val_loss: 0.7210 - val_acc: 0.7520
# Epoch 38/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3604 - acc: 0.8514 - val_loss: 0.5705 - val_acc: 0.7712
# Epoch 39/100
# 156/156 [==============================] - 193s 1s/step - loss: 0.3423 - acc: 0.8657 - val_loss: 0.5822 - val_acc: 0.7571
# Epoch 40/100
# 156/156 [==============================] - 193s 1s/step - loss: 0.3424 - acc: 0.8610 - val_loss: 0.6044 - val_acc: 0.7651
# Epoch 41/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3368 - acc: 0.8623 - val_loss: 0.3293 - val_acc: 0.8921
# Epoch 42/100
# 156/156 [==============================] - 194s 1s/step - loss: 0.3242 - acc: 0.8665 - val_loss: 0.6671 - val_acc: 0.7339
# Epoch 43/100
# 156/156 [==============================] - 193s 1s/step - loss: 0.3455 - acc: 0.8588 - val_loss: 0.7161 - val_acc: 0.7500
# Epoch 44/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3289 - acc: 0.8756 - val_loss: 2.4130 - val_acc: 0.4688
# Epoch 45/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3229 - acc: 0.8704 - val_loss: 0.5554 - val_acc: 0.8125
# Epoch 46/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3165 - acc: 0.8769 - val_loss: 0.6997 - val_acc: 0.7440
# Epoch 47/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3261 - acc: 0.8712 - val_loss: 0.5871 - val_acc: 0.7833
# Epoch 48/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3299 - acc: 0.8656 - val_loss: 0.4164 - val_acc: 0.8468
# Epoch 49/100
# 156/156 [==============================] - 192s 1s/step - loss: 0.3142 - acc: 0.8789 - val_loss: 0.4240 - val_acc: 0.8337
# Epoch 50/100
# 156/156 [==============================] - 198s 1s/step - loss: 0.3049 - acc: 0.8750 - val_loss: 0.5170 - val_acc: 0.8034
# Epoch 51/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.3285 - acc: 0.8711 - val_loss: 0.8445 - val_acc: 0.6865
# Epoch 52/100
# 156/156 [==============================] - 201s 1s/step - loss: 0.3156 - acc: 0.8764 - val_loss: 0.6123 - val_acc: 0.7812
# Epoch 53/100
# 156/156 [==============================] - 201s 1s/step - loss: 0.2990 - acc: 0.8814 - val_loss: 0.3461 - val_acc: 0.8599
# Epoch 54/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.2894 - acc: 0.8874 - val_loss: 0.7802 - val_acc: 0.7308
# Epoch 55/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.3010 - acc: 0.8856 - val_loss: 0.2989 - val_acc: 0.8821
# Epoch 56/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.3117 - acc: 0.8784 - val_loss: 0.8079 - val_acc: 0.6472
# Epoch 57/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.2987 - acc: 0.8819 - val_loss: 0.5451 - val_acc: 0.7923
# Epoch 58/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.3142 - acc: 0.8788 - val_loss: 0.4625 - val_acc: 0.8296
# Epoch 59/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.2902 - acc: 0.8828 - val_loss: 0.5653 - val_acc: 0.7853
# Epoch 60/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.3136 - acc: 0.8730 - val_loss: 1.0339 - val_acc: 0.6905
# Epoch 61/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.3104 - acc: 0.8776 - val_loss: 0.3513 - val_acc: 0.8619
# Epoch 62/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.2819 - acc: 0.8890 - val_loss: 0.5004 - val_acc: 0.8256
# Epoch 63/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2980 - acc: 0.8827 - val_loss: 0.8771 - val_acc: 0.7026
# Epoch 64/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.2934 - acc: 0.8921 - val_loss: 0.6570 - val_acc: 0.7651
# Epoch 65/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.2615 - acc: 0.8973 - val_loss: 0.3110 - val_acc: 0.8841
# Epoch 66/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.2918 - acc: 0.8913 - val_loss: 0.3281 - val_acc: 0.8710
# Epoch 67/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.2747 - acc: 0.8883 - val_loss: 0.4625 - val_acc: 0.8266
# Epoch 68/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.2842 - acc: 0.8999 - val_loss: 0.5594 - val_acc: 0.8054
# Epoch 69/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.2719 - acc: 0.8962 - val_loss: 0.7534 - val_acc: 0.7480
# Epoch 70/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2762 - acc: 0.8837 - val_loss: 0.3448 - val_acc: 0.8740
# Epoch 71/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2817 - acc: 0.8862 - val_loss: 0.5726 - val_acc: 0.7278
# Epoch 72/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2664 - acc: 0.8903 - val_loss: 0.3826 - val_acc: 0.8569
# Epoch 73/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.2635 - acc: 0.8993 - val_loss: 0.5396 - val_acc: 0.8095
# Epoch 74/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2842 - acc: 0.8961 - val_loss: 0.5338 - val_acc: 0.8085
# Epoch 75/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2699 - acc: 0.8890 - val_loss: 1.8032 - val_acc: 0.5292
# Epoch 76/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2551 - acc: 0.8979 - val_loss: 0.5499 - val_acc: 0.8135
# Epoch 77/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.2507 - acc: 0.9048 - val_loss: 0.4246 - val_acc: 0.8468
# Epoch 78/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2678 - acc: 0.8959 - val_loss: 0.8076 - val_acc: 0.7026
# Epoch 79/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2739 - acc: 0.8958 - val_loss: 0.6819 - val_acc: 0.7863
# Epoch 80/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2604 - acc: 0.9002 - val_loss: 0.4469 - val_acc: 0.8286
# Epoch 81/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2532 - acc: 0.9049 - val_loss: 0.3544 - val_acc: 0.8569
# Epoch 82/100
# 156/156 [==============================] - 200s 1s/step - loss: 0.2538 - acc: 0.9019 - val_loss: 0.3526 - val_acc: 0.8629
# Epoch 83/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2502 - acc: 0.9099 - val_loss: 0.4748 - val_acc: 0.8276
# Epoch 84/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2483 - acc: 0.9036 - val_loss: 0.2971 - val_acc: 0.8901
# Epoch 85/100
# 156/156 [==============================] - 199s 1s/step - loss: 0.2465 - acc: 0.9009 - val_loss: 0.4979 - val_acc: 0.8256
# Epoch 86/100
# 156/156 [==============================] - 204s 1s/step - loss: 0.2561 - acc: 0.8998 - val_loss: 0.2660 - val_acc: 0.9022
# Epoch 87/100
# 156/156 [==============================] - 189s 1s/step - loss: 0.2484 - acc: 0.9047 - val_loss: 0.8853 - val_acc: 0.7077
# Epoch 88/100
# 156/156 [==============================] - 188s 1s/step - loss: 0.2389 - acc: 0.9039 - val_loss: 0.5847 - val_acc: 0.7782
# Epoch 89/100
# 156/156 [==============================] - 188s 1s/step - loss: 0.2392 - acc: 0.9094 - val_loss: 0.7068 - val_acc: 0.7933
# Epoch 90/100
# 156/156 [==============================] - 187s 1s/step - loss: 0.2631 - acc: 0.8951 - val_loss: 0.3853 - val_acc: 0.8468
# Epoch 91/100
# 156/156 [==============================] - 187s 1s/step - loss: 0.2463 - acc: 0.9065 - val_loss: 0.3849 - val_acc: 0.8599
# Epoch 92/100
# 156/156 [==============================] - 187s 1s/step - loss: 0.2364 - acc: 0.9111 - val_loss: 0.4716 - val_acc: 0.8438
# Epoch 93/100
# 156/156 [==============================] - 188s 1s/step - loss: 0.2348 - acc: 0.9083 - val_loss: 1.2956 - val_acc: 0.6462
# Epoch 94/100
# 156/156 [==============================] - 188s 1s/step - loss: 0.2406 - acc: 0.9088 - val_loss: 0.3080 - val_acc: 0.8942
# Epoch 95/100
# 156/156 [==============================] - 187s 1s/step - loss: 0.2450 - acc: 0.9070 - val_loss: 0.8868 - val_acc: 0.7480
# Epoch 96/100
# 156/156 [==============================] - 187s 1s/step - loss: 0.2638 - acc: 0.8977 - val_loss: 0.8620 - val_acc: 0.7530
# Epoch 97/100
# 156/156 [==============================] - 187s 1s/step - loss: 0.2254 - acc: 0.9136 - val_loss: 0.2729 - val_acc: 0.8901
# Epoch 98/100
# 156/156 [==============================] - 187s 1s/step - loss: 0.2376 - acc: 0.9070 - val_loss: 0.3037 - val_acc: 0.8891
# Epoch 99/100
# 156/156 [==============================] - 187s 1s/step - loss: 0.2167 - acc: 0.9117 - val_loss: 0.5419 - val_acc: 0.7883
# Epoch 100/100
# 156/156 [==============================] - 187s 1s/step - loss: 0.2523 - acc: 0.9035 - val_loss: 0.4512 - val_acc: 0.8438

# %%
#Plot the Graph

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# Accuracy Curves
plt.figure(1)
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy for all four class')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('acc7.png')
plt.show()

# loss Curves
plt.figure(2)
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss all four class')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('loss7.png')
plt.show()

# %%
#Print the Target names
target_names = []
for key in train_generator.class_indices:
    target_names.append(key)
    
print(target_names)
# Out:
# ['background', 'lizard', 'snake', 'toad']

# %%
#Get the accuracy score
Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
#print('Confusion Matrix')
import itertools
#Plot the confusion matrix. Set Normalize = True/False
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix of all four class', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    #plt.figure(figsize=(8,8))

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    #plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    #plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
   

#thresh = cm.max() / 2.
#Matplotlib’s matshow
cm = confusion_matrix(test_generator.classes, y_pred)

plt.figure(3)
plot_confusion_matrix(cm, target_names, title='Confusion Matrix')
#print(cm)
plt.savefig('allfour_Conf_CNN2.png')
plt.show()
# Out:
# Confusion matrix, without normalization

# %%
#Print Classification Report
print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#   background       0.49      0.58      0.53       100
#       lizard       0.66      0.91      0.76       100
#        snake       0.96      0.68      0.80       100
#         toad       0.97      0.71      0.82       100
#
#     accuracy                           0.72       400
#    macro avg       0.77      0.72      0.73       400
# weighted avg       0.77      0.72      0.73       400
